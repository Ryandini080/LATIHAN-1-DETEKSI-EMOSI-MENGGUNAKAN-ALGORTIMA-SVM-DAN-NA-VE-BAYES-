# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from nltk.stem import PorterStemmer
from sklearn import metrics

# %% [markdown]
# Soal Latihan: Silahkan kalian perbaiki lagi dari preprocessing maupun aspek lainnya
# ataupun mencoba dengan metode baru untuk meningkatkan akurasi!

# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from nltk.stem import PorterStemmer
from sklearn import metrics

import pandas as pd  

df = pd.read_csv(r"C:\Users\Acer\Documents\Teknik Elektro\Semester 7\Mechine Learning\Praktikum 1-1\Praktikum 1\Bahan data\ISEAR.csv", header=None)
df.iloc[4:10]
# Out:
#          0                                                  1    2
# 4  disgust  At a gathering I found myself involuntarily si...  NaN
# 5    shame  When I realized that I was directing the feeli...  NaN
# 6    guilt  I feel guilty when when I realize that I consi...  NaN
# 7      joy  After my girlfriend had taken her exam we went...  NaN
# 8     fear  When, for the first time I realized the meanin...  NaN
# 9    anger  When a car is overtaking another and I am forc...  NaN

# %%
import pandas as pd

col = [0, 1]
new_df = df[col]
new_df = new_df[new_df[1].notnull()]
new_df.columns = ['Emotion', 'Text']
result = new_df.iloc[4:10]
print(result)
# Out:
#    Emotion                                               Text
# 4  disgust  At a gathering I found myself involuntarily si...
# 5    shame  When I realized that I was directing the feeli...
# 6    guilt  I feel guilty when when I realize that I consi...
# 7      joy  After my girlfriend had taken her exam we went...
# 8     fear  When, for the first time I realized the meanin...
# 9    anger  When a car is overtaking another and I am forc...

# %%
import pandas as pd
import matplotlib.pyplot as plt

col = [0, 1]
new_df = df[col]
new_df = new_df[new_df[1].notnull()]
new_df.columns = ['Emotion', 'Text']
data_subset = new_df.iloc[4:10]
emotion_counts = data_subset['Emotion'].value_counts()

plt.figure(figsize=(8, 6))
emotion_counts.plot(kind='bar', color='skyblue')
plt.title('Emotion Distribution (Data ke-5 sampai ke-10)')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn import metrics

Y_test_subset = Y_test.iloc[4:10]  
myPredTest_subset = myPredTest[4:10]  

print('Metrics Classification Report: SVM (Data ke-5 sampai ke-10)')
classification_report = metrics.classification_report(Y_test_subset, myPredTest_subset)

print(classification_report)
# Out:
# Metrics Classification Report: SVM (Data ke-5 sampai ke-10)
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00         1
#      disgust       1.00      1.00      1.00         1
#         fear       0.00      0.00      0.00         0
#        guilt       1.00      1.00      1.00         1
#          joy       0.00      0.00      0.00         1
#      sadness       1.00      1.00      1.00         1
#        shame       1.00      1.00      1.00         1
#
#     accuracy                           0.67         6
#    macro avg       0.57      0.57      0.57         6
# weighted avg       0.67      0.67      0.67         6
# C:\Users\Acer\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt  

labels = ['anger', 'disgust', 'fear', 'guilt', 'joy', 'sadness', 'shame']
Y_test_subset = Y_test.iloc[4:10]  
myPredTest_subset = myPredTest[4:10]  
cm_subset = confusion_matrix(Y_test_subset, myPredTest_subset, labels=labels)
fig, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(cm_subset, annot=True, fmt='d',
            xticklabels=labels, yticklabels=labels, cmap='Blues')

plt.ylabel('Actual Emotions')
plt.xlabel('Predicted Emotions')
plt.title('Confusion Matrix (Data ke-5 sampai ke-10)')
plt.show()
